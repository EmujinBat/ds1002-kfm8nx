# %% [markdown]
# <a href="https://colab.research.google.com/github/EmujinBat/ds1002-kfm8nx/blob/main/panda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt #matplotlib is library; pyplot is the class
# %matplotlib inline

# %%
#import the mackoroo file
mock_data = pd.read_csv("MOCK_DATA.csv") #pd is the library; read_cvs is the command

# %%
mock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   int64
#  1   first_name  1000 non-null   object
#  2   last_name   1000 non-null   object
#  3   email       1000 non-null   object
#  4   gender      1000 non-null   object
#  5   age         1000 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 47.0+ KB

# %%
mock_data.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
#get the head rows
#how many rows you want to see in the brackets
mock_data.head(3)
# Out:
#    id first_name last_name                           email  gender  age
# 0   1        Tam     Reeve                treeve0@army.mil    Male   70
# 1   2       Barr      Riba          briba1@telegraph.co.uk    Male   67
# 2   3   Sara-ann   Lorking  slorking2@pagesperso-orange.fr  Female   83

# %%
#from the tail
mock_data.tail(3)
# Out:
#        id first_name last_name                   email  gender  age
# 997   998      Lorry   Offener      loffenerrp@loc.gov    Male   52
# 998   999      Kenon   Priddey    kpriddeyrq@sogou.com    Male   51
# 999  1000   Natalina   Garrick  ngarrickrr@typepad.com  Female   11

# %%
#get by the index of the row 0th index would give first row
#rectangular brackets
mock_data.loc[0]
# Out:
# id                           1
# first_name                 Tam
# last_name                Reeve
# email         treeve0@army.mil
# gender                    Male
# age                         70
# Name: 0, dtype: object

# %%
#describe finds mathematical properties of the number table
mock_data.describe()
# Out:
#                 id          age
# count  1000.000000  1000.000000
# mean    500.500000    45.535000
# std     288.819436    25.502532
# min       1.000000     1.000000
# 25%     250.750000    24.000000
# 50%     500.500000    45.000000
# 75%     750.250000    67.000000
# max    1000.000000    90.000000

# %%
# get the columns from the df
# what are the columns of this data table?
mock_data.columns
# it will give a list---- we can populate with this thing
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'age'], dtype='object')

# %%
# Getting the types
mock_data.dtypes
# Out:
# id             int64
# first_name    object
# last_name     object
# email         object
# gender        object
# age            int64
# dtype: object

# %%
# overriding/modifying
mock_data = mock_data.rename(columns={"first_name":"fname","last_name":"lname"})

# %%
mock_data.head()
# Out:
#    id     fname      lname                           email  gender  age
# 0   1       Tam      Reeve                treeve0@army.mil    Male   70
# 1   2      Barr       Riba          briba1@telegraph.co.uk    Male   67
# 2   3  Sara-ann    Lorking  slorking2@pagesperso-orange.fr  Female   83
# 3   4  Maryanne  Shilstone           mshilstone3@webmd.com  Female   71
# 4   5     Edyth   Claypool   eclaypool4@simplemachines.org  Female   40

# %%
# getting columns out
mock_data['fname']
# Out:
# 0           Tam
# 1          Barr
# 2      Sara-ann
# 3      Maryanne
# 4         Edyth
#          ...
# 995      Kelsey
# 996        Xena
# 997       Lorry
# 998       Kenon
# 999    Natalina
# Name: fname, Length: 1000, dtype: object

# %%
# The second way to get columns out
# fname is a sequence in the data frame. Calling this data frame.
mock_data.fname
# Out:
# 0           Tam
# 1          Barr
# 2      Sara-ann
# 3      Maryanne
# 4         Edyth
#          ...
# 995      Kelsey
# 996        Xena
# 997       Lorry
# 998       Kenon
# 999    Natalina
# Name: fname, Length: 1000, dtype: object

# %%
# Getting multiple columns
mock_data[['fname','lname']]
# Out:
#         fname      lname
# 0         Tam      Reeve
# 1        Barr       Riba
# 2    Sara-ann    Lorking
# 3    Maryanne  Shilstone
# 4       Edyth   Claypool
# ..        ...        ...
# 995    Kelsey  Magarrell
# 996      Xena    Restall
# 997     Lorry    Offener
# 998     Kenon    Priddey
# 999  Natalina    Garrick
#
# [1000 rows x 2 columns]

# %%
# getting a plot from all of the gender values
pd.value_counts(mock_data['gender']).plot.bar()
# Out:
# <Axes: >

# %%
mock_data.groupby(['gender'])['age'].mean()
# Out:
# gender
# Agender        48.166667
# Bigender       43.684211
# Female         46.436242
# Genderfluid    52.692308
# Genderqueer    45.227273
# Male           44.884701
# Non-binary     36.590909
# Polygender     45.857143
# Name: age, dtype: float64
