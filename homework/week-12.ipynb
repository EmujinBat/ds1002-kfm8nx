# %% [markdown]
# <a href="https://colab.research.google.com/github/EmujinBat/ds1002-kfm8nx/blob/main/homework/week-12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pie Chart (3 points)

# %%
# Create a pie chart from raw values

slices = [56, 66, 24, 124, 47]
labels = ["US","UK","MX","CA","JP"]

# %%
import matplotlib.pyplot as plt

slices = [56, 66, 24, 124, 47]
plt.pie(slices, labels = ["US","UK","MX","CA","JP"])
plt.title("Countries and numbers")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Histogram (3 points)

# %%
# Create a histogram from random data

import matplotlib.pyplot as plt
import numpy as np

n = 430 + np.random.randn(3000)
plt.hist(n, bins = 25, color = "blue")
# Out:
# (array([  2.,   1.,   1.,  11.,  25.,  36.,  78., 138., 192., 224., 286.,
#         308., 303., 311., 289., 263., 182., 120.,  94.,  56.,  34.,  26.,
#          13.,   4.,   3.]),
#  array([426.60203019, 426.87226714, 427.14250409, 427.41274104,
#         427.68297799, 427.95321494, 428.22345189, 428.49368884,
#         428.76392579, 429.03416274, 429.30439969, 429.57463664,
#         429.84487358, 430.11511053, 430.38534748, 430.65558443,
#         430.92582138, 431.19605833, 431.46629528, 431.73653223,
#         432.00676918, 432.27700613, 432.54724308, 432.81748003,
#         433.08771698, 433.35795393]),
#  <BarContainer object of 25 artists>)

# %% [markdown]
# ## Scatterplot with Trendline (3 points)

# %%
# Create a scatterplot with a trendline from two lists of values

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

num_points = 50
x = 5 + np.arange(num_points) + np.random.randn(num_points)
y = 10 + np.arange(num_points) + 5 * np.random.randn(num_points)

plt.scatter(x,y)
a = np.polyfit(x,y, 2)
b = np.poly1d(a)

plt.plot(x, b(x))
plt.scatter(x,y)
# If you want them combined into a dataframe
df = pd.DataFrame({'x': x, 'y': y})
